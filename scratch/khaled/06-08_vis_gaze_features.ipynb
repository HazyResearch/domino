# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import mosaic as ms
import matplotlib.pyplot as plt

from domino.data.cxr import get_dp, build_cxr_df
from domino.vis import visualize_gaze_dp

# %%
build_cxr_df(root_dir="/media/4tb_hdd/siim/")
# Out:
# task: build_cxr_df, run_id=42
# task: create_gaze_df, run_id=43

# %%
# Get a mosaic DataPanel with the data.
df = build_cxr_df.out(load=True)
dp = get_dp(df)
dp.head()
# Out:
# DataPanel(num_rows: 5)

# %%
dp.lz[dp["gaze_seq"].data != "nan"].head()
# Out:
# DataPanel(num_rows: 5)

# %%
visualize_gaze_dp(dp, num_examples=2, rle_column="encoded_pixels", class_value=1, run_dir="./imgs/.")
