# %%
from meerkat.contrib.gqa import read_gqa_dps
import numpy as np
import meerkat as mk

# %%
dps = read_gqa_dps("/home/common/datasets/gqa")

# %%
mk.config.DisplayOptions.max_image_width = 1024
mk.config.DisplayOptions.max_image_height = 1024

# %%
object_dp = dps["objects"]
image_dp = dps["images"]
snow_images = object_dp.lz[object_dp["name"] == "snow"]["image_id"]
car_images = object_dp.lz[object_dp["name"] == "car"]["image_id"]

# %%
dp = image_dp.lz[np.isin(image_dp["image_id"], np.array(list(set(snow_images) & set(car_images))))]

# %%
x = 130
dp["image"].lz[x: x+10]
# Out:
# ImageColumn(PandasSeriesC...dtype: object))
