# %%
# %load_ext autoreload
# %autoreload 2

import subprocess
from google.cloud import storage
import os
import PIL
import terra
import pandas as pd
import numpy as np
import meerkat as mk
import torchxrayvision as xrv
from domino.data.mimic import build_dp, mimic_transform

from domino.evaluate.linear import induce_correlation, check_corr_induction
from domino.evaluate.train import train_linear_slices
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dp = build_dp(
    dataset_dir="/home/common/datasets/mimic", 
    gcp_project="hai-gcp-fine-grained"
)
# Out:
# task: build_dp, run_id=1267

# %%
dp = build_dp.out(1267, load=True)

# %%
train_linear_slices.out(691).load()
# Out:
#               target   correlate  corr  num_examples  run_id  \
# 0               male     smiling   0.0       30000.0     694
# 1               male     smiling   0.1       30000.0     693
# 2               male     smiling   0.2       30000.0     692
# 3               male     smiling   0.3       30000.0     695
# 4               male     smiling   0.4       30000.0     696
# ..               ...         ...   ...           ...     ...
# 94  wearing_necklace  blond_hair   0.4       30000.0     786
# 95  wearing_necklace  blond_hair   0.5       30000.0     787
# 96  wearing_necklace  blond_hair   0.6       30000.0     788
# 97  wearing_necklace  blond_hair   0.7       30000.0     789
# 98  wearing_necklace  blond_hair   0.8       30000.0     790
#
#     time_this_iter_s   done  timesteps_total  episodes_total  \
# 0         708.509146  False              NaN             NaN
# 1         726.495500  False              NaN             NaN
# 2         739.591141  False              NaN             NaN
# 3         733.769021  False              NaN             NaN
# 4         760.407439  False              NaN             NaN
# ..               ...    ...              ...             ...
# 94        772.858852  False              NaN             NaN
# 95        816.905568  False              NaN             NaN
# 96        741.073604  False              NaN             NaN
# 97        745.519187  False              NaN             NaN
# 98        738.802351  False              NaN             NaN
#
#     training_iteration  ...     pid        hostname    node_ip  \
# 0                    1  ...   24613  pod-sabri-t4-4  10.92.5.4
# 1                    1  ...   24612  pod-sabri-t4-4  10.92.5.4
# 2                    1  ...   24616  pod-sabri-t4-4  10.92.5.4
# 3                    1  ...   24609  pod-sabri-t4-4  10.92.5.4
# 4                    1  ...   24615  pod-sabri-t4-4  10.92.5.4
# ..                 ...  ...     ...             ...        ...
# 94                   1  ...  373212  pod-sabri-t4-4  10.92.5.4
# 95                   1  ...  373506  pod-sabri-t4-4  10.92.5.4
# 96                   1  ...  381664  pod-sabri-t4-4  10.92.5.4
# 97                   1  ...  386895  pod-sabri-t4-4  10.92.5.4
# 98                   1  ...  387210  pod-sabri-t4-4  10.92.5.4
#
#     time_since_restore  timesteps_since_restore iterations_since_restore  \
# 0           708.509146                        0                        1
# 1           726.495500                        0                        1
# 2           739.591141                        0                        1
# 3           733.769021                        0                        1
# 4           760.407439                        0                        1
# ..                 ...                      ...                      ...
# 94          772.858852                        0                        1
# 95          816.905568                        0                        1
# 96          741.073604                        0                        1
# 97          745.519187                        0                        1
# 98          738.802351                        0                        1
#
#        trial_id  config/corr             config/target_correlate  \
# 0   8a3f0_00000          0.0                 ['male', 'smiling']
# 1   8a3f0_00001          0.1                 ['male', 'smiling']
# 2   8a3f0_00002          0.2                 ['male', 'smiling']
# 3   8a3f0_00003          0.3                 ['male', 'smiling']
# 4   8a3f0_00004          0.4                 ['male', 'smiling']
# ..          ...          ...                                 ...
# 94  8a3f0_00094          0.4  ['wearing_necklace', 'blond_hair']
# 95  8a3f0_00095          0.5  ['wearing_necklace', 'blond_hair']
# 96  8a3f0_00096          0.6  ['wearing_necklace', 'blond_hair']
# 97  8a3f0_00097          0.7  ['wearing_necklace', 'blond_hair']
# 98  8a3f0_00098          0.8  ['wearing_necklace', 'blond_hair']
#
#                                                logdir
# 0   /root/ray_results/_train_model_2021-06-29_07-2...
# 1   /root/ray_results/_train_model_2021-06-29_07-2...
# 2   /root/ray_results/_train_model_2021-06-29_07-2...
# 3   /root/ray_results/_train_model_2021-06-29_07-2...
# 4   /root/ray_results/_train_model_2021-06-29_07-2...
# ..                                                ...
# 94  /root/ray_results/_train_model_2021-06-29_07-2...
# 95  /root/ray_results/_train_model_2021-06-29_07-2...
# 96  /root/ray_results/_train_model_2021-06-29_07-2...
# 97  /root/ray_results/_train_model_2021-06-29_07-2...
# 98  /root/ray_results/_train_model_2021-06-29_07-2...
#
# [99 rows x 24 columns]

# %%
with open("/home/sabri/terra/slice/tasks/evaluate/train/train_linear_slices/_runs/1302/task.log") as f:
    log = f.read()
run_ids = list(map(int, re.findall("run_id=(\d+)", log)))

# %%
df = []
for run_id in run_ids[1:]:
    try: 
        df.append(terra.out(run_id))
    except FileNotFoundError:
        pass

df = pd.DataFrame(df)

# %%
df.to_csv("/home/sabri/terra/slice/tasks/evaluate/train/train_linear_slices/_runs/1302/artifacts/out", index=False)

# %%
import re

run_ids = list(map(int, re.findall("run_id=(\d+)", log)))
run_ids
# Out:
# [1302,
#  1303,
#  1304,
#  1305,
#  1306,
#  1307,
#  1308,
#  1309,
#  1310,
#  1311,
#  1312,
#  1313,
#  1314,
#  1315,
#  1316,
#  1317,
#  1318,
#  1319,
#  1320,
#  1321,
#  1322,
#  1323,
#  1324,
#  1325,
#  1326,
#  1327,
#  1328,
#  1329,
#  1330,
#  1331,
#  1332,
#  1333,
#  1334,
#  1335,
#  1336,
#  1337,
#  1338,
#  1339,
#  1340,
#  1341,
#  1342,
#  1343,
#  1344,
#  1345,
#  1346,
#  1347,
#  1348,
#  1349,
#  1350,
#  1351,
#  1352,
#  1353,
#  1354,
#  1355,
#  1356,
#  1357,
#  1358,
#  1359,
#  1360,
#  1361,
#  1362,
#  1363,
#  1364,
#  1365,
#  1366,
#  1367,
#  1368,
#  1369,
#  1370,
#  1371,
#  1372,
#  1373,
#  1374,
#  1390,
#  1396,
#  1403,
#  1404,
#  1415,
#  1416,
#  1423,
#  1426,
#  1429,
#  1430,
#  1431,
#  1432,
#  1433,
#  1434,
#  1435,
#  1436,
#  1437,
#  1438,
#  1439,
#  1440,
#  1441,
#  1442,
#  1443,
#  1444,
#  1445,
#  1446,
#  1447,
#  1448,
#  1449,
#  1450,
#  1451,
#  1452,
#  1453,
#  1454,
#  1455,
#  1456]

# %%
check_corr_induction(
    dp=build_dp.out(1267),
    attributes=[
        "patient_orientation_rf",
        "young",
        "ethnicity_black",
        "ethnicity_hisp",
        "ethnicity_asian",
        "burned_in_annotation",
        "gender_male",
        "Edema_uzeros",
        "Pleural_Effusion_uzeros",
        "Support_Devices_uzeros",
        "Enlarged_Cardiomediastinum_uzeros",
        "Lung_Lesion_uzeros"
    ],
    corr_start=0,
    corr_end=0.8,
    n=30000
)
# Out:
# task: check_corr_induction, run_id=1270
#   0%|          | 0/12 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/home/sabri/code/terra/terra/__init__.py", line 230, in _run
#     out = self.fn(**args_dict)
#   File "/home/sabri/code/domino/domino/evaluate/linear.py", line 152, in check_corr_induction
#     induce_correlation(
#   File "/home/sabri/code/domino/domino/evaluate/linear.py", line 74, in induce_correlation
#     elif int(n_b1) > df[attr_b].sum():
# ValueError: cannot convert float NaN to integer
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-901e9b1bfc77> in <module>
# ----> 1 check_corr_induction(
#       2     dp=dp,
#       3     attributes=[
#       4         "patient_orientation_rf",
#       5         "young",
#
# /home/sabri/code/terra/terra/__init__.py in __call__(self, *args, **kwargs)
#     121
#     122     def __call__(self, *args, **kwargs):
# --> 123         return self._run(*args, **kwargs)
#     124
#     125     def _run(self, *args, **kwargs):
#
# /home/sabri/code/terra/terra/__init__.py in _run(self, *args, **kwargs)
#     253             print(msg)
#     254             session.close()
# --> 255             raise e
#     256
#     257         if return_run_id:
#
# /home/sabri/code/terra/terra/__init__.py in _run(self, *args, **kwargs)
#     228
#     229             # run function
# --> 230             out = self.fn(**args_dict)
#     231
#     232             # write outputs
#
# /home/sabri/code/domino/domino/evaluate/linear.py in check_corr_induction(dp, attributes, corr_start, corr_end, run_dir, **kwargs)
#     150             for corr in corrs:
#     151                 try:
# --> 152                     induce_correlation(
#     153                         dp, corr=corr, attr_a=attr_a, attr_b=attr_b, **kwargs
#     154                     )
#
# /home/sabri/code/domino/domino/evaluate/linear.py in induce_correlation(df, corr, n, attr_a, attr_b, mu_a, mu_b, match_mu, replace)
#      72     if int(n_a1) > df[attr_a].sum():
#      73         msg = "Not enough samples where a=1. Try a lower mu_a."
# ---> 74     elif int(n_b1) > df[attr_b].sum():
#      75         msg = "Not enough samples where b=1. Try a lower mu_b."
#      76     elif int(n_1) > both_1.sum():
#
# ValueError: cannot convert float NaN to integer

# %%
out = induce_correlation(
    df=dp,
    corr=0,
    attr_a="Pleural_Effusion_uzeros",
    attr_b="young",
    n=30000,
    match_mu=True
)

# %%
# Out:
# array(["['A', 'F']", "['F', 'A']", "['F', 'L']", "['F', 'R']",
#        "['H', 'L']", "['L', 'F']", "['LP', 'F']", "['R', 'F']"],
#       dtype=object)

# %%
dp["patient_orientation_rf"]  = dp["PatientOrientation"].data == "['R', 'F']"

# %%
dp["young"] = (dp["anchor_age"] < 40)

# %%
pd.Series(dp["BurnedInAnnotation"].data).unique()
# Out:
# array(['YES', 'NO'], dtype=object)

# %%
dp["BurnedInAnnotation"].mean()
# Out:
# 0.0

# %%
dp.columns
# Out:
# ['dicom_id',
#  'subject_id_x',
#  'study_id',
#  'path',
#  'subject_id_1',
#  'study_id_1',
#  'path_1',
#  'subject_id_2',
#  'study_id_2',
#  'Atelectasis',
#  'Cardiomegaly',
#  'Consolidation',
#  'Edema',
#  'Enlarged_Cardiomediastinum',
#  'Fracture',
#  'Lung_Lesion',
#  'Lung_Opacity',
#  'No_Finding',
#  'Pleural_Effusion',
#  'Pleural_Other',
#  'Pneumonia',
#  'Pneumothorax',
#  'Support_Devices',
#  'subject_id_3',
#  'gender',
#  'anchor_age',
#  'anchor_year',
#  'anchor_year_group',
#  'dod',
#  'dicom',
#  'StudyDate_x',
#  'ImageType',
#  'TableType',
#  'DistanceSourceToDetector',
#  'DistanceSourceToPatient',
#  'Exposure',
#  'ExposureTime',
#  'XRayTubeCurrent',
#  'FieldOfViewRotation',
#  'FieldOfViewOrigin',
#  'FieldOfViewHorizontalFlip',
#  'ViewPosition',
#  'PatientOrientation',
#  'BurnedInAnnotation',
#  'RequestingService',
#  'DetectorPrimaryAngle',
#  'DetectorElementPhysicalSize',
#  'subject_id_y',
#  'StudyDate_y',
#  'hadm_id',
#  'admittime',
#  'dischtime',
#  'deathtime',
#  'admission_type',
#  'admission_location',
#  'discharge_location',
#  'insurance',
#  'language',
#  'marital_status',
#  'ethnicity',
#  'edregtime',
#  'edouttime',
#  'hospital_expire_flag',
#  'jpg_path',
#  'img',
#  'split',
#  'index',
#  'img_512',
#  'input_224',
#  'input_512',
#  'Atelectasis_uzeros',
#  'Cardiomegaly_uzeros',
#  'Consolidation_uzeros',
#  'Edema_uzeros',
#  'Enlarged_Cardiomediastinum_uzeros',
#  'Fracture_uzeros',
#  'Lung_Lesion_uzeros',
#  'Lung_Opacity_uzeros',
#  'No_Finding_uzeros',
#  'Pleural_Effusion_uzeros',
#  'Pleural_Other_uzeros',
#  'Pneumonia_uzeros',
#  'Pneumothorax_uzeros',
#  'Support_Devices_uzeros',
#  'male',
#  'patient_orientatino_lf',
#  'patient_orientatino_rf',
#  'patient_orientation_rf',
#  'young',
#  'ethnicity_black']
