# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# (1) Compute predictions and CLIP embeddings for each example in the validation set
# (2) Compute CLIP embeddings for common concepts in the domain
# (3) Cluster the image CLIP embeddings to find subgroups
#     - Interesting sub-question, how to do clustering, such that we find high loss clusters
# (4) For each cluster:
#     - "Explain" the cluster by computing the average embedding for the cluster - the average embedding in the dataset, and comparing to all the concept embeddings.

# %%
import terra
from meerkat.contrib.visual_genome import read_visual_genome_dps
from domino.data.visual_genome import get_dps, ATTRIBUTE_GROUPS
import numpy as np
from domino.utils import get_data_dir
data_dir = get_data_dir()

# %% [markdown]
# ## Create DataPanels for the Visual Genome
#
# `image_dp` - each row corresponds to an image in the dataset
# `object_dp`– each row corresponds to an object (e.g. 'car') in one of the images
# `attr_dp`- each row maps an attribute (e.g. 'red') to an object

# %%
image_dp, attr_dp, object_dp = get_dps()

# %% [markdown]
# ## Create a classification task
# We're going to use the visual genome to craft a binary image classification task.
# `target` = 1 if the object is a car and `target` = 0 otherwise.
#
# We're also going to keep track of a potential confounder: "color".

# %%
def get_vg_task():

    # filter to only include objects with an annotated color 
    colored_objects = attr_dp["object_id"][
        attr_dp["attribute"].isin(ATTRIBUTE_GROUPS["colors"])
    ]
    dp = object_dp.lz[np.isin(object_dp["object_id"], colored_objects)]

    # set the target column to "is car?"
    dp["target"] = dp["syn_name"].isin(["car.n.01"]).values.astype(int)

    # set the correlate column to "is red?"
    red_objects = attr_dp["object_id"][
        attr_dp["attribute"].isin(["red"])
    ]
    dp["correlate"] = np.isin(dp["object_id"], red_objects).astype(int)

# %%
dp.lz[(dp["target"] & dp["correlate"]) == 1]["object_image"][2]
# Out:
# <PIL.Image.Image image mode=RGB size=353x258 at 0x7FC903FFD6D0>

# %% [markdown]
# ## Induce correlation
# Let's induce an artificial correlation between cars and the color red.

# %%
from domino.evaluate.linear import induce_correlation

# %%
indices = induce_correlation(
    dp, 
    corr=0.8, 
    mu_a=0.05,
    mu_b=0.05,
    attr_a="target", 
    attr_b="correlate", 
    n=2e4
)
dataset_dp = dp.lz[indices]

# %%
from scipy.stats import pearsonr
pearsonr(dataset_dp["target"], dataset_dp["correlate"])
# Out:
# (0.7998092834663161, 0.0)

# %% [markdown]
# ## Train a Model
# Train a model on this subsampled dataset

# %%
from domino.utils import split_dp

# %%
dataset_dp = split_dp(dataset_dp, split_on="image_id")

# %%
import terra 
from domino.vision import train
from torchvision import transforms
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])
preprocessing = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    normalize,
])

dataset_dp["input"] = dataset_dp["object_image"].to_lambda(preprocessing)

@terra.Task.make_task
def train_vg(dp, run_dir: str = None):

    model = train(
        config={"pretrained": True},
        dp=dp,
        input_column="input",
        id_column="object_id",
        target_column="target",
        ckpt_monitor="valid_auroc",
        batch_size=128, 
        run_dir=run_dir,
        val_check_interval=10,
        num_workers=6
    )
    return model
train_vg(dp=dataset_dp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-148-617b88324b51> in <module>
#      11 ])
#      12
# ---> 13 dataset_dp["input"] = dataset_dp["object_image"].to_lambda(preprocessing)
#      14
#      15 @terra.Task.make_task
#
# /home/sabri/code/meerkat/meerkat/mixins/lambdable.py in to_lambda(self, fn)
#      12         from meerkat import LambdaColumn
#      13
# ---> 14         return LambdaColumn(data=self, fn=fn)
#
# /home/sabri/code/meerkat/meerkat/columns/lambda_column.py in __init__(self, data, fn, output_type, *args, **kwargs)
#      60         **kwargs,
#      61     ):
# ---> 62         super(LambdaColumn, self).__init__(data.view(), *args, **kwargs)
#      63         if fn is not None:
#      64             self.fn = fn
#
# TypeError: super(type, obj): obj must be an instance or subtype of type

# %%
dataset_dp = terra.inp(4514)["dp"].load()

# %%
model = terra.get_artifacts(4514, "best_chkpt")["model"]

# %% [markdown]
# ## Score model
# Let's score the model and evaluate on subgroups.

# %%
from domino.vision import score
score_dp = score(
    model=model.load(), 
    dp=dataset_dp.lz[dataset_dp["split"] == "test"], 
    input_column="input",
    batch_size=128
)
# Out:
# /home/common/envs/conda/envs/domino/lib/python3.8/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `AUROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# HBox(children=(FloatProgress(value=0.0, max=32.0), HTML(value='')))

# %%
score_dp["prob"] = score_dp["output"].probabilities().data[:, -1]

# %%
from sklearn.metrics import roc_auc_score
print("Overall AUROC: {}".format(
    roc_auc_score(score_dp["target"], score_dp["prob"])
))

curr_dp = score_dp.lz[score_dp["target"] == score_dp["correlate"]]
print("AUROC where correlation holds: {}".format(
    roc_auc_score(curr_dp["target"], curr_dp["prob"])
))

curr_dp = score_dp.lz[score_dp["target"] != score_dp["correlate"]]
print("AUROC where correlation does not hold: {}".format(
    roc_auc_score(curr_dp["target"], curr_dp["prob"])
))
# Out:
# Overall AUROC: 0.9467894162575013
# AUROC where correlation holds: 0.9611383824216924
# AUROC where correlation does not hold: 0.7887205387205387

# %% [markdown]
# ## Embed in CLIP space to recover spurious correlate

# %%
from domino.clip import embed_images
score_dp = embed_images(dp=score_dp, img_column="object_image")
# Out:
# HBox(children=(FloatProgress(value=0.0, max=32.0), HTML(value='')))

# %%
from domino.clip import embed_words
#words_dp = embed_words(words_dp).load()
words_dp = embed_words.out(4508).load()
words_dp = words_dp.lz[:int(1e4)]

# %%
score_dp.lz[score_dp["target"] != score_dp["correlate"]]
# Out:
# DataPanel(nrows: 69, ncols: 24)

# %%
error_dp = score_dp.lz[(dp["prob"] > 0.7).numpy() != (dp["target"] == 1)]
error_dp
# Out:
# DataPanel(nrows: 91, ncols: 24)

# %%
row = error_dp[15]
print(f"prediction:{row['prob']}")
print(f"target:{row['target']}")
row["object_image"]
# Out:
# prediction:0.996006190776825
# target:0
# <PIL.Image.Image image mode=RGB size=54x54 at 0x7F1A60161E50>

# %%
error_dp

import wandb
import pandas as pd

table = wandb.Table(dataframe=pd.DataFrame({
    "target": error_dp["target"].data,
    "prob": error_dp["prob"].data,
}))
table.add_column(name="object_image", data=[wandb.Image(img) for img in error_dp["image"]])

# %%
run = wandb.init()
run.log({"table_key": table})
# Out:
# wandb: Currently logged in as: hazy-research (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">prime-dragon-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hazy-research/domino-scratch_sabri" target="_blank">https://wandb.ai/hazy-research/domino-scratch_sabri</a><br/>
#                 Run page: <a href="https://wandb.ai/hazy-research/domino-scratch_sabri/runs/14zav5en" target="_blank">https://wandb.ai/hazy-research/domino-scratch_sabri/runs/14zav5en</a><br/>
#                 Run data is saved locally in <code>/home/sabri/code/domino/scratch/sabri/wandb/run-20210821_174018-14zav5en</code><br/><br/>

# %%
dp = score_dp
attr_emb = dp.lz[(dp["prob"] > 0.5).numpy()]["emb"].data.numpy().mean(axis=0)
ref_emb = dp.lz[dp["target"] == 1]["emb"].data.numpy().mean(axis=0)

scores = np.dot( 
    words_dp["emb"].data.numpy(),   
    (attr_emb - ref_emb) 
)
words_dp.lz[(-scores).argsort()[:20]]
# Out:
# DataPanel(nrows: 20, ncols: 5)

# %%
dp.lz[(dp["prob"] > 0.5).numpy() != dp["target"].data]['target'].mean()
# Out:
# 0.6585365853658537

# %%
import glob
import random
import base64
import pandas as pd

from PIL import Image
from io import BytesIO
from IPython.display import HTML
import io

def image_base64(im):
    with BytesIO() as buffer:
        im.save(buffer, 'jpeg')
        return base64.b64encode(buffer.getvalue()).decode()

def image_formatter(im, max_width: int = 128, max_height: int = 128):
    im = im.get()
    im.thumbnail((max_width, max_height))
    return f'<img src="data:image/jpeg;base64,{image_base64(im)}">'

# %%
from IPython.core.display import HTML


dp = dataset_dp
df = dp.lz[:100].to_pandas()
HTML(df.to_html(
    escape=False, 
    formatters={"object_image": image_formatter, "image": image_formatter},
    col_space={"object_image": 128, "image": 128},
    justify="center",
    max_rows=10
),
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: center;">
#       <th></th>
#       <th>image_id</th>
#       <th>height</th>
#       <th>url</th>
#       <th>width</th>
#       <th>index</th>
#       <th>local_path</th>
#       <th style="min-width: 128px;">image</th>
#       <th>h</th>
#       <th>name</th>
#       <th>object_id</th>
#       <th>syn_name</th>
#       <th>w</th>
#       <th>x</th>
#       <th>y</th>
#       <th style="min-width: 128px;">object_image</th>
#       <th>target</th>
#       <th>correlate</th>
#       <th>split_hash</th>
#       <th>split</th>
#       <th>input</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2397661</td>
#       <td>500</td>
#       <td>https://cs.stanford.edu/people/rak248/VG_100K_2/2397661.jpg</td>
#       <td>398</td>
#       <td>719464</td>
#       <td>/home/common/datasets/visual-genome/VG_100K_2/2397661.jpg</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>102</td>
#       <td>head</td>
#       <td>1187827</td>
#       <td>head.n.01</td>
#       <td>74</td>
#       <td>77</td>
#       <td>287</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.24245</td>
#       <td>train</td>
#       <td>LambdaCell</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2059</td>
#       <td>600</td>
#       <td>https://cs.stanford.edu/people/rak248/VG_100K_2/2059.jpg</td>
#       <td>800</td>
#       <td>67238</td>
#       <td>/home/common/datasets/visual-genome/VG_100K_2/2059.jpg</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>83</td>
#       <td>frame</td>
#       <td>1546382</td>
#       <td>frame.n.01</td>
#       <td>69</td>
#       <td>334</td>
#       <td>148</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.40108</td>
#       <td>train</td>
#       <td>LambdaCell</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2375172</td>
#       <td>500</td>
#       <td>https://cs.stanford.edu/people/rak248/VG_100K/2375172.jpg</td>
#       <td>375</td>
#       <td>1280113</td>
#       <td>/home/common/datasets/visual-genome/VG_100K/2375172.jpg</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>70</td>
#       <td>pants</td>
#       <td>583809</td>
#       <td>trouser.n.01</td>
#       <td>134</td>
#       <td>4</td>
#       <td>428</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.15222</td>
#       <td>train</td>
#       <td>LambdaCell</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2319462</td>
#       <td>500</td>
#       <td>https://cs.stanford.edu/people/rak248/VG_100K/2319462.jpg</td>
#       <td>375</td>
#       <td>3430677</td>
#       <td>/home/common/datasets/visual-genome/VG_100K/2319462.jpg</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>121</td>
#       <td>banana is yellow</td>
#       <td>1001808</td>
#       <td>banana.n.01</td>
#       <td>97</td>
#       <td>26</td>
#       <td>180</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.79307</td>
#       <td>valid</td>
#       <td>LambdaCell</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2366814</td>
#       <td>500</td>
#       <td>https://cs.stanford.edu/people/rak248/VG_100K/2366814.jpg</td>
#       <td>333</td>
#       <td>1597675</td>
#       <td>/home/common/datasets/visual-genome/VG_100K/2366814.jpg</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>19</td>
#       <td>number</td>
#       <td>753652</td>
#       <td>numeral.n.01</td>
#       <td>14</td>
#       <td>103</td>
#       <td>264</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.72986</td>
#       <td>valid</td>
#       <td>LambdaCell</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>2334173</td>
#       <td>375</td>
#       <td>https://cs.stanford.edu/people/rak248/VG_100K/2334173.jpg</td>
#       <td>500</td>
#       <td>2902193</td>
#       <td>/home/common/datasets/visual-genome/VG_100K/2334173.jpg</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>162</td>
#       <td>wall</td>
#       <td>2735949</td>
#       <td>wall.n.01</td>
#       <td>67</td>
#       <td>431</td>
#       <td>154</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.28960</td>
#       <td>train</td>
#       <td>LambdaCell</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>2367035</td>
#       <td>500</td>
#       <td>https://cs.stanford.edu/people/rak248/VG_100K/2367035.jpg</td>
#       <td>500</td>
#       <td>1588418</td>
#       <td>/home/common/datasets/visual-genome/VG_100K/2367035.jpg</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>30</td>
#       <td>sky</td>
#       <td>1844077</td>
#       <td>sky.n.01</td>
#       <td>40</td>
#       <td>188</td>
#       <td>0</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.99007</td>
#       <td>test</td>
#       <td>LambdaCell</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>2362952</td>
#       <td>375</td>
#       <td>https://cs.stanford.edu/people/rak248/VG_100K/2362952.jpg</td>
#       <td>500</td>
#       <td>1750496</td>
#       <td>/home/common/datasets/visual-genome/VG_100K/2362952.jpg</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>130</td>
#       <td>flower</td>
#       <td>2639887</td>
#       <td>flower.n.01</td>
#       <td>85</td>
#       <td>353</td>
#       <td>44</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.20883</td>
#       <td>train</td>
#       <td>LambdaCell</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>2370629</td>
#       <td>375</td>
#       <td>https://cs.stanford.edu/people/rak248/VG_100K/2370629.jpg</td>
#       <td>500</td>
#       <td>1455217</td>
#       <td>/home/common/datasets/visual-genome/VG_100K/2370629.jpg</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>19</td>
#       <td>cardigan</td>
#       <td>3857655</td>
#       <td>cardigan.n.01</td>
#       <td>18</td>
#       <td>477</td>
#       <td>333</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.93949</td>
#       <td>test</td>
#       <td>LambdaCell</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>2385634</td>
#       <td>500</td>
#       <td>https://cs.stanford.edu/people/rak248/VG_100K_2/2385634.jpg</td>
#       <td>332</td>
#       <td>992697</td>
#       <td>/home/common/datasets/visual-genome/VG_100K_2/2385634.jpg</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>76</td>
#       <td>handle</td>
#       <td>3845811</td>
#       <td>handle.n.01</td>
#       <td>22</td>
#       <td>261</td>
#       <td>197</td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.96829</td>
#       <td>test</td>
#       <td>LambdaCell</td>
#     </tr>
#   </tbody>
# </table>

# %%
from meerkat.nn import EmbeddingColumn
umap = EmbeddingColumn(score_dp["emb"]).umap().embeddings

# %%
dataset_dp
# Out:
# DataPanel(nrows: 19998, ncols: 20)

# %%
score_dp["umap_0"], score_dp["umap_1"] = umap[:, 0], umap[:, 1]

# %%
import seaborn as sns 
plot_df = score_dp[["umap_0", "umap_1", "correlate", "target"]].to_pandas()

sns.scatterplot(data=plot_df, x="umap_0", y="umap_1", hue="correlate", alpha=0.3)
# Out:
# <AxesSubplot:xlabel='umap_0', ylabel='umap_1'>

# %%
g = sns.FacetGrid(plot_df, col="target", hue="correlate", sharex=False, sharey=False)
g.map(sns.scatterplot, "umap_0", "umap_1")

# %%
words_dp
# Out:
# DataPanel(nrows: 10000, ncols: 5)
