# %%
# %load_ext autoreload
# %autoreload 2

from tqdm import tqdm
import terra
import numpy as np
import meerkat as mk
from meerkat.contrib.mimic import build_mimic_dp
from domino.data.mimic import build_dp
import sys
from domino.evaluate.evaluate import run_sdm, evaluate_sdms

# %%
data_dp, _ = terra.out(1664, load=True)

# %%
import meerkat.contrib.mimic 
from domino.evaluate.evaluate import run_sdm, evaluate_sdms
out = run_sdm(**run_sdm.inp(2439))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-ca92be8fe9f1> in <module>
#       1 import meerkat.contrib.mimic
#       2 from domino.evaluate.evaluate import run_sdm, evaluate_sdms
# ----> 3 out = run_sdm(**run_sdm.inp(2439))
#
# /home/sabri/code/terra/terra/__init__.py in inp(self, run_id, load)
#      49         if run_id is None:
#      50             run_id = _get_latest_run_id(self.task_dir)
# ---> 51         inps = json_load(
#      52             os.path.join(
#      53                 _get_run_dir(task_dir=self.task_dir, idx=run_id), "inputs.json"
#
# /home/sabri/code/terra/terra/io.py in json_load(path)
#     145
#     146 def json_load(path: str):
# --> 147     with open(path) as f:
#     148         decoder = TerraDecoder()
#     149         return decoder.decode(f.read())
#
# ...

# %%
from domino.evaluate.evaluate import run_sdm, evaluate_sdms

df = evaluate_sdms.out().load()
df.iloc[200:220]
# Out:
#      run_id                   target             correlate  corr  \
# 200    2631             Edema_uzeros       ethnicity_asian   0.6
# 201    2630             Edema_uzeros       ethnicity_asian   0.8
# 202    2653             Edema_uzeros       ethnicity_asian   0.8
# 203    2632             Edema_uzeros       ethnicity_asian   0.8
# 204    2633  Pleural_Effusion_uzeros  burned_in_annotation   0.0
# 205    2657  Pleural_Effusion_uzeros  burned_in_annotation   0.0
# 206    2637  Pleural_Effusion_uzeros  burned_in_annotation   0.0
# 207    2638  Pleural_Effusion_uzeros  burned_in_annotation   0.1
# 208    2656  Pleural_Effusion_uzeros  burned_in_annotation   0.1
# 209    2642  Pleural_Effusion_uzeros  burned_in_annotation   0.1
# 210    2643  Pleural_Effusion_uzeros  burned_in_annotation   0.2
# 211    2655  Pleural_Effusion_uzeros  burned_in_annotation   0.2
# 212    2650  Pleural_Effusion_uzeros  burned_in_annotation   0.2
# ...

# %%
from domino.evaluate.evaluate import run_sdm, evaluate_sdms
evaluate_sdms.get_runs()
# Out:
#       id                    module             fn  \
# 0   2317  domino.evaluate.evaluate  evaluate_sdms
# 1   2213  domino.evaluate.evaluate  evaluate_sdms
# 2   2191  domino.evaluate.evaluate  evaluate_sdms
# 3   2087  domino.evaluate.evaluate  evaluate_sdms
# 4   2080  domino.evaluate.evaluate  evaluate_sdms
# 5   2073  domino.evaluate.evaluate  evaluate_sdms
# 6   2022  domino.evaluate.evaluate  evaluate_sdms
# 7   1996  domino.evaluate.evaluate  evaluate_sdms
# 8   1989  domino.evaluate.evaluate  evaluate_sdms
# 9   1988  domino.evaluate.evaluate  evaluate_sdms
# 10  1987  domino.evaluate.evaluate  evaluate_sdms
# 11  1956  domino.evaluate.evaluate  evaluate_sdms
# 12  1749  domino.evaluate.evaluate  evaluate_sdms
# 13  1742  domino.evaluate.evaluate  evaluate_sdms
# 14  1735  domino.evaluate.evaluate  evaluate_sdms
# 15  1734  domino.evaluate.evaluate  evaluate_sdms
# 16  1733  domino.evaluate.evaluate  evaluate_sdms
# 17  1728  domino.evaluate.evaluate  evaluate_sdms
# ...

# %%
# Out:
# {'y': 12, 'x': 12, 'z': 12}
